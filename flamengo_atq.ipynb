# %%
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf

# %%
lib19=pd.read_csv('https://raw.githubusercontent.com/mths-andrade/flamengo/main/lib%2019.csv')
lib20=pd.read_csv('https://raw.githubusercontent.com/mths-andrade/flamengo/main/lib%2020.csv')
lib21=pd.read_csv('https://raw.githubusercontent.com/mths-andrade/flamengo/main/lib%2021.csv')
lib22=pd.read_csv('https://raw.githubusercontent.com/mths-andrade/flamengo/main/lib%2022.csv')
lib23=pd.read_csv('https://raw.githubusercontent.com/mths-andrade/flamengo/main/lib%2023.csv')

# %%
lib19['data'] = pd.to_datetime(lib19['data'], format='%Y-%m-%d')
lib20['data'] = pd.to_datetime(lib20['data'], format='%Y-%m-%d')
lib21['data'] = pd.to_datetime(lib21['data'], format='%Y-%m-%d')
lib22['data'] = pd.to_datetime(lib22['data'], format='%Y-%m-%d')
lib23['data'] = pd.to_datetime(lib23['data'], format='%Y-%m-%d')

# %%
def plot_comparacao(x, y1, y2, y3, dataset, titulo):
	plt.figure(figsize=(12,6))
	ax = plt.subplot(3,1,1)
	ax.set_title(titulo,fontsize=18, loc='left')
	sns.lineplot(x=x, y=y1, data=dataset, marker='o')
	plt.subplot(3,1,2)
	sns.lineplot(x=x, y=y2, data=dataset, marker='o')
	plt.subplot(3,1,3)
	sns.lineplot(x=x, y=y3, data=dataset, marker='o')
	ax=ax

# %%
def sumario(formula,dataset):
  resultado=smf.ols(formula=formula, data=dataset).fit()
  print(resultado.summary())

# %%
def regressao(x,y,dataset,titulo):
  ax=sns.lmplot(x=x,y=y,data=dataset)
  ax.fig.suptitle(titulo,y=1.05)

# %%
plot_comparacao('data','fin_alvo','fin_fora','gols',lib19,'Finalizações e gols Libertadores 2019')

# %%
sumario('fin_alvo ~ gols',lib19)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               fin_alvo   R-squared:                       0.731
# Model:                            OLS   Adj. R-squared:                  0.707
# Method:                 Least Squares   F-statistic:                     29.91
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):           0.000195
# Time:                        18:14:47   Log-Likelihood:                -24.790
# No. Observations:                  13   AIC:                             53.58
# Df Residuals:                      11   BIC:                             54.71
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.0000      0.705      4.253      0.001       1.447       4.553
# gols           1.5000      0.274      5.469      0.000       0.896       2.104
# ==============================================================================
# Omnibus:                        1.927   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.382   Jarque-Bera (JB):                0.946
# Skew:                           0.200   Prob(JB):                        0.623
# Kurtosis:                       1.741   Cond. No.                         4.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   res = hypotest_fun_out(*samples, **kwds)

# %%
regressao('fin_alvo','gols',lib19,"Finalizações por alvo X gols Libertadores 2019")

# %%
plot_comparacao('data','fin_alvo','fin_fora','gols',lib20,'Finalizações e gols Libertadores 2020')

# %%
sumario('fin_alvo ~ gols',lib20)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               fin_alvo   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                     16.44
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):            0.00669
# Time:                        18:14:48   Log-Likelihood:                -11.729
# No. Observations:                   8   AIC:                             27.46
# Df Residuals:                       6   BIC:                             27.62
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.2917      0.820      2.796      0.031       0.286       4.297
# gols           1.4167      0.349      4.054      0.007       0.562       2.272
# ==============================================================================
# Omnibus:                        1.421   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.491   Jarque-Bera (JB):                0.662
# Skew:                           0.050   Prob(JB):                        0.718
# Kurtosis:                       1.594   Cond. No.                         5.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   res = hypotest_fun_out(*samples, **kwds)

# %%
regressao('fin_alvo','gols',lib20,"Finalizações por alvo X gols Libertadores 2020")

# %%
plot_comparacao('data','fin_alvo','fin_fora','gols',lib21,'Finalizações e gols Libertadores 2021')

# %%
sumario('fin_alvo ~ gols',lib21)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               fin_alvo   R-squared:                       0.488
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                     10.48
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):            0.00792
# Time:                        18:14:51   Log-Likelihood:                -25.718
# No. Observations:                  13   AIC:                             55.44
# Df Residuals:                      11   BIC:                             56.57
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.0427      1.096      2.775      0.018       0.629       5.456
# gols           1.2256      0.379      3.237      0.008       0.392       2.059
# ==============================================================================
# Omnibus:                        1.756   Durbin-Watson:                   2.747
# Prob(Omnibus):                  0.416   Jarque-Bera (JB):                1.105
# Skew:                           0.433   Prob(JB):                        0.576
# Kurtosis:                       1.864   Cond. No.                         6.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   res = hypotest_fun_out(*samples, **kwds)

# %%
regressao('fin_alvo','gols',lib21,"Finalizações por alvo X gols Libertadores 2021")

# %%
plot_comparacao('data','fin_alvo','fin_fora','gols',lib22,'Finalizações e gols Libertadores 2022')

# %%
sumario('fin_alvo ~ gols',lib22)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               fin_alvo   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     81.08
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):           2.09e-06
# Time:                        18:14:53   Log-Likelihood:                -18.516
# No. Observations:                  13   AIC:                             41.03
# Df Residuals:                      11   BIC:                             42.16
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.5296      0.582      2.629      0.023       0.249       2.810
# gols           1.7611      0.196      9.005      0.000       1.331       2.192
# ==============================================================================
# Omnibus:                        0.952   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.621   Jarque-Bera (JB):                0.829
# Skew:                          -0.486   Prob(JB):                        0.661
# Kurtosis:                       2.236   Cond. No.                         6.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   res = hypotest_fun_out(*samples, **kwds)

# %%
regressao('fin_alvo','gols',lib22,"Finalizações por alvo X gols Libertadores 2022")

# %%
plot_comparacao('data','fin_alvo','fin_fora','gols',lib23,'Finalizações e gols Libertadores 2023')

# %%
sumario('fin_alvo ~ gols',lib23)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               fin_alvo   R-squared:                       0.605
# Model:                            OLS   Adj. R-squared:                  0.539
# Method:                 Least Squares   F-statistic:                     9.191
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):             0.0230
# Time:                        18:14:55   Log-Likelihood:                -14.257
# No. Observations:                   8   AIC:                             32.51
# Df Residuals:                       6   BIC:                             32.67
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.4603      1.126      1.296      0.242      -1.296       4.217
# gols           1.7937      0.592      3.032      0.023       0.346       3.241
# ==============================================================================
# Omnibus:                        0.814   Durbin-Watson:                   1.805
# Prob(Omnibus):                  0.666   Jarque-Bera (JB):                0.621
# Skew:                          -0.358   Prob(JB):                        0.733
# Kurtosis:                       1.837   Cond. No.                         4.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   res = hypotest_fun_out(*samples, **kwds)

# %%
fla=pd.read_csv('https://raw.githubusercontent.com/mths-andrade/flamengo/main/flamengo.csv')

# %%
plot_comparacao('ano','fin_alvo','fin_fora','gols',fla,'Finalizações e gols por ano')

# %%
sumario('fin_alvo ~ gols',fla)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               fin_alvo   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     67.31
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):            0.00379
# Time:                        18:18:28   Log-Likelihood:                -20.372
# No. Observations:                   5   AIC:                             44.74
# Df Residuals:                       3   BIC:                             43.96
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -21.0060     42.512     -0.494      0.655    -156.299     114.287
# gols           3.2042      0.391      8.204      0.004       1.961       4.447
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.148
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.313
# Skew:                          -1.254   Prob(JB):                        0.519
# Kurtosis:                       2.918   Cond. No.                         563.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
x = lib22.fin_alvo
y = lib22.gols

ax = sns.scatterplot(data=lib22, x="fin_alvo", y="gols")
ax.figure.set_size_inches(10, 6)
ax.set_title("Finalizações realizadas no alvo X gols na Libertadores de 2022")
ax.hlines(y = y.mean(), xmin = x.min(), xmax = x.max(), colors='crimson', linestyles='dashed')
ax.vlines(x = x.mean(), ymin = y.min(), ymax = y.max(), colors='black', linestyles='dashed')
ax.text(6.1, 6.8, 'Média das finalizações no gol', fontsize=10, color = 'black', va = "bottom")
ax.text(2, 2.7, 'Média dos gols', fontsize=10, color = 'crimson', ha = "left")
plt.show()
